# %% [markdown]
# # Part 4: Lightgbm
#
#  - Objective: Analyze changes in Data Science and Analytics (DSA) job content over the past 10 months in Taipei.
#
#  - Data Collection: Compilation of job data in Taipei, focusing on positions related to Data Science and Analytics.
#
#  - Data Scope: The dataset includes some positions that may not be directly relevant to DSA.
#
#  - Initial Step: Filter out job postings that are not pertinent to DSA.
#
#  - Analysis Method: Employ dynamic topic modeling to identify shifts in the content of DSA job descriptions during the 10-month period.

# %%
import utils, umap, json
import pandas as pd
import numpy as np
import lightgbm as lgb
from sklearn.cluster import HDBSCAN
from sklearn.metrics import roc_curve, accuracy_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split, GridSearchCV
from scipy.spatial.distance import cosine
import plotly.express as px
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data/20231119_job_market_job.csv")
list_job_name_embeddings = json.load(open("data/20231119_job_market_job_name_embeddings.json", "r"))

# %%
keywords = ["數據科學", "資料科學", "數據工程", "資料工程", "資料庫", "演算法",
            "機器學習", "人工智慧", "人工智能", "數據分析", "自然語言", "電腦視覺",
            "資料分析", "商業分析", "產品分析", "data science",
            "data engineering", "database", "algorithm", "machine learning",
            "artificial intelligence", "natural language", "computer vision",
            "data analysis", "business analysis", "product analysis"]

# %%
data["job_name"].str.lower()
data["contain_keyword"] = data["job_name"].str.contains("|".join(keywords))
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28777 entries, 0 to 28776
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               28777 non-null  object
#  1   job_name         28777 non-null  object
#  2   job_desc         28752 non-null  object
#  3   contain_keyword  28777 non-null  bool
# dtypes: bool(1), object(3)
# memory usage: 702.7+ KB

# %%
X_train, X_test, y_train, y_test = train_test_split(list_job_name_embeddings, data["contain_keyword"].tolist(),
                                                    test_size=0.3, random_state=69)

# %%
param_grid = {
    "boosting_type": ["gbdt", "dart"],
    "num_leaves": [10, 20, 30],
    "learning_rate": [0.1, 0.01, 0.001],
    "n_estimators": [100, 200, 300],
    "objective": ["binary"],
    "random_state": [69]
}

# %%
lgb_model = lgb.LGBMClassifier()

grid_search = GridSearchCV(estimator=lgb_model, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.100856 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.101625 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.103356 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1044, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.104939 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064784 -> initscore=-2.669713
# [LightGBM] [Info] Start training from score -2.669713
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15072
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.100518 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064722 -> initscore=-2.670738
# [LightGBM] [Info] Start training from score -2.670738
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.104307 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.104213 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.113607 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1044, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.127313 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064784 -> initscore=-2.669713
# [LightGBM] [Info] Start training from score -2.669713
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15072
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.113918 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064722 -> initscore=-2.670738
# [LightGBM] [Info] Start training from score -2.670738
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.131041 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.111090 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.112487 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1044, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.097463 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064784 -> initscore=-2.669713
# [LightGBM] [Info] Start training from score -2.669713
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15072
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.111435 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064722 -> initscore=-2.670738
# [LightGBM] [Info] Start training from score -2.670738
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.094457 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.119483 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.117527 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1044, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.123726 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064784 -> initscore=-2.669713
# [LightGBM] [Info] Start training from score -2.669713
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15072
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.125722 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064722 -> initscore=-2.670738
# [LightGBM] [Info] Start training from score -2.670738
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.112849 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.093463 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.097422 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1044, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.096027 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064784 -> initscore=-2.669713
# [LightGBM] [Info] Start training from score -2.669713
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15072
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.090600 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064722 -> initscore=-2.670738
# [LightGBM] [Info] Start training from score -2.670738
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.092551 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.087343 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.099008 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1044, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.092066 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064784 -> initscore=-2.669713
# [LightGBM] [Info] Start training from score -2.669713
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15072
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.101194 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064722 -> initscore=-2.670738
# [LightGBM] [Info] Start training from score -2.670738
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.095647 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.108590 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.093703 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1044, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.100226 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064784 -> initscore=-2.669713
# [LightGBM] [Info] Start training from score -2.669713
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15072
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.101678 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064722 -> initscore=-2.670738
# [LightGBM] [Info] Start training from score -2.670738
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.097582 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.101170 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.090691 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1044, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.103469 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064784 -> initscore=-2.669713
# [LightGBM] [Info] Start training from score -2.669713
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15072
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.091562 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064722 -> initscore=-2.670738
# [LightGBM] [Info] Start training from score -2.670738
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.098170 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.098412 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.100646 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 1044, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.098098 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064784 -> initscore=-2.669713
# [LightGBM] [Info] Start training from score -2.669713
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15072
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.102534 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064722 -> initscore=-2.670738
# [LightGBM] [Info] Start training from score -2.670738
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.108324 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.110814 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.106557 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1044, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.096119 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064784 -> initscore=-2.669713
# [LightGBM] [Info] Start training from score -2.669713
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15072
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.100351 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064722 -> initscore=-2.670738
# [LightGBM] [Info] Start training from score -2.670738
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.098850 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.096010 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.100351 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1044, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.102106 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064784 -> initscore=-2.669713
# [LightGBM] [Info] Start training from score -2.669713
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15072
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.096522 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064722 -> initscore=-2.670738
# [LightGBM] [Info] Start training from score -2.670738
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.096185 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.093964 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.092761 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1044, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.097716 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064784 -> initscore=-2.669713
# [LightGBM] [Info] Start training from score -2.669713
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15072
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.089693 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064722 -> initscore=-2.670738
# [LightGBM] [Info] Start training from score -2.670738
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.106553 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.094120 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.096493 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1044, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.093531 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064784 -> initscore=-2.669713
# [LightGBM] [Info] Start training from score -2.669713
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15072
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.095909 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064722 -> initscore=-2.670738
# [LightGBM] [Info] Start training from score -2.670738
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.124694 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.090452 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.090059 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1044, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.087294 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064784 -> initscore=-2.669713
# [LightGBM] [Info] Start training from score -2.669713
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15072
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.096534 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064722 -> initscore=-2.670738
# [LightGBM] [Info] Start training from score -2.670738
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.095068 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.090896 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.087535 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1044, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.089042 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# ...
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064722 -> initscore=-2.670738
# [LightGBM] [Info] Start training from score -2.670738
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.104102 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.096957 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.099223 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1044, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.093100 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064784 -> initscore=-2.669713
# [LightGBM] [Info] Start training from score -2.669713
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15072
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.107237 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064722 -> initscore=-2.670738
# [LightGBM] [Info] Start training from score -2.670738
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.097483 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.093920 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.122290 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1044, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.092799 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064784 -> initscore=-2.669713
# [LightGBM] [Info] Start training from score -2.669713
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15072
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.093770 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064722 -> initscore=-2.670738
# [LightGBM] [Info] Start training from score -2.670738
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.189630 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.090086 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.104269 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1044, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.085931 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064784 -> initscore=-2.669713
# [LightGBM] [Info] Start training from score -2.669713
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15072
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.111332 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064722 -> initscore=-2.670738
# [LightGBM] [Info] Start training from score -2.670738
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.093726 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.090822 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.092967 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1044, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.092370 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064784 -> initscore=-2.669713
# [LightGBM] [Info] Start training from score -2.669713
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15072
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.093118 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064722 -> initscore=-2.670738
# [LightGBM] [Info] Start training from score -2.670738
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.122963 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.088342 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.091295 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1044, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.095428 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064784 -> initscore=-2.669713
# [LightGBM] [Info] Start training from score -2.669713
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15072
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.089892 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064722 -> initscore=-2.670738
# [LightGBM] [Info] Start training from score -2.670738
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.087241 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.101012 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.083011 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16114, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064726 -> initscore=-2.670671
# [LightGBM] [Info] Start training from score -2.670671
# [LightGBM] [Info] Number of positive: 1044, number of negative: 15071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.089525 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064784 -> initscore=-2.669713
# [LightGBM] [Info] Start training from score -2.669713
# [LightGBM] [Info] Number of positive: 1043, number of negative: 15072
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.088244 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 16115, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064722 -> initscore=-2.670738
# [LightGBM] [Info] Start training from score -2.670738
# [LightGBM] [Info] Number of positive: 1304, number of negative: 18839
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.109636 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 20143, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064737 -> initscore=-2.670493
# [LightGBM] [Info] Start training from score -2.670493
# GridSearchCV(cv=5, estimator=LGBMClassifier(),
#              param_grid={'boosting_type': ['gbdt', 'dart'],
#                          'learning_rate': [0.1, 0.01, 0.001],
#                          'n_estimators': [100, 200, 300],
#                          'num_leaves': [10, 20, 30], 'objective': ['binary'],
#                          'random_state': [69]})

# %% [markdown]
# The Best Model Paramaters were:
# ```
# best_params = {
#     'boosting_type': 'gbdt',
#     'learning_rate': 0.1,
#     'n_estimators': 300,
#     'num_leaves': 10,
#     'objective': 'binary',
#     'random_state': 69
#     }
#  ```

# %%
best_params = grid_search.best_params_
print(best_params)
# Out:
# {'boosting_type': 'gbdt', 'learning_rate': 0.1, 'n_estimators': 300, 'num_leaves': 10, 'objective': 'binary', 'random_state': 69}

# %%
final_model = lgb.LGBMClassifier(**best_params)
final_model.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Number of positive: 1304, number of negative: 18839
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.112409 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 391680
# [LightGBM] [Info] Number of data points in the train set: 20143, number of used features: 1536
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.064737 -> initscore=-2.670493
# [LightGBM] [Info] Start training from score -2.670493
# LGBMClassifier(n_estimators=300, num_leaves=10, objective='binary',
#                random_state=69)

# %%
y_pred = final_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
print(pd.DataFrame(confusion_matrix(y_test, y_pred), index = ["Actual Negative", "Actual Positive"], columns = ["Predicted Negative", "Predicted Positive"]))
# Out:
# 0.9813527912902479
#                  Predicted Negative  Predicted Positive
# Actual Negative                8028                  47
# Actual Positive                 114                 445
